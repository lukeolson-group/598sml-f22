# %% [markdown]
# # Approximating a 1D function

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Define a nonlinear function f(x) that we want to approximate

# %%
def f(x):
    #return torch.where(x < 0, torch.cos(x/3), torch.sin(1/(x/2+0.1)))
    return torch.where(x < 0, torch.cos(x/3), 0.5*torch.sin(8*x - 1.5*x**2) + 0.5*x - 0.1*x**2)

x = torch.linspace(-3, 6, 200)
y = f(x)
plt.plot(x.numpy(), y.numpy(), 'b')
plt.xlabel('x')
plt.ylabel('f(x)');

# %% [markdown]
# ## Tasks

# %% [markdown]
# 1. Use a fully-connected NN to approximate the function $f(x)$ defined above.
#
# 2. How many layers and what layer widths do you need to get a good approximation?
#
# 3. What optimizer parameters did you need to use?
#
# 4. Make a movie of how the model predictions evolve as the optimization proceeds.
#
# ### Parameters and hyper-parameters
#
# The NN weights and biases are called the _parameters_ of the network.
#
# The NN layer widths, number of layers, optimizer learning rate, etc., are call _hyper-parameters_.
